# %% [markdown]
# # 1. Load Libraries

# %%
import matplotlib
from matplotlib import colors
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt, numpy as np
from matplotlib.colors import ListedColormap

# %%
import pandas as pd
import datetime
import seaborn as sns
from yellowbrick.cluster import KElbowVisualizer
from mpl_toolkits.mplot3d import Axes3D
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
np.random.seed(42)
from scipy.stats import ttest_ind

# %% [markdown]
# # 2. Load Data

# %%
df = pd.read_csv("final_dataset.csv")

# %% [markdown]
# # 3. Inspect Data

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
print(df.shape)
# Out:
# (2208, 44)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      2208 non-null   int64
#  1   year_birth              2208 non-null   int64
#  2   education               2208 non-null   int64
#  3   marital_status          2208 non-null   int64
#  4   income                  2208 non-null   int64
#  5   kidhome                 2208 non-null   int64
#  6   teenhome                2208 non-null   int64
#  7   dt_customer             2208 non-null   str
#  8   recency                 2208 non-null   int64
#  9   mntwines                2208 non-null   int64
#  10  mntfruits               2208 non-null   int64
#  11  mntmeatproducts         2208 non-null   int64
#  12  mntfishproducts         2208 non-null   int64
#  13  mntsweetproducts        2208 non-null   int64
# ...

# %% [markdown]
# # 4. Cluster 1

# %%
cluster_1_table = (
    pd.DataFrame([{
        "cluster": 1,
        "numwebvisitsmonth": df.loc[df["cluster"] == 1, "numwebvisitsmonth"].mean(),
        "totalspending": df.loc[df["cluster"] == 1, "totalspending"].mean(),
        "totalpurchases": df.loc[df["cluster"] == 1, "totalpurchases"].mean(),
        "familysize": df.loc[df["cluster"] == 1, "familysize"].mean(),
        "spendingincomeratio": df.loc[df["cluster"] == 1, "spendingincomeratio"].mean(),
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_1_table
# Out:
# <style type="text/css">
# #T_39af6 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_39af6_row0_col0, #T_39af6_row0_col1, #T_39af6_row0_col2, #T_39af6_row0_col3, #T_39af6_row0_col4, #T_39af6_row0_col5 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_39af6">
#   <thead>
#     <tr>
#       <th id="T_39af6_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_39af6_level0_col1" class="col_heading level0 col1" >numwebvisitsmonth</th>
#       <th id="T_39af6_level0_col2" class="col_heading level0 col2" >totalspending</th>
#       <th id="T_39af6_level0_col3" class="col_heading level0 col3" >totalpurchases</th>
#       <th id="T_39af6_level0_col4" class="col_heading level0 col4" >familysize</th>
#       <th id="T_39af6_level0_col5" class="col_heading level0 col5" >spendingincomeratio</th>
#     </tr>
#   </thead>
# ...

# %%
cluster_1_table = (
    pd.DataFrame([{
        "cluster": 1,
        "webconversionrate": df.loc[df["cluster"] == 1, "webconversionrate"].mean(),
        "dealpurchaseratio": df.loc[df["cluster"] == 1, "dealpurchaseratio"].mean(),
        "age": df.loc[df["cluster"] == 1, "age"].mean(),
        "income": df.loc[df["cluster"] == 1, "income"].mean(),
        "education": df.loc[df["cluster"] == 1, "education"].mode().iloc[0],
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_1_table
# Out:
# <style type="text/css">
# #T_43719 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_43719_row0_col0, #T_43719_row0_col1, #T_43719_row0_col2, #T_43719_row0_col3, #T_43719_row0_col4, #T_43719_row0_col5 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_43719">
#   <thead>
#     <tr>
#       <th id="T_43719_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_43719_level0_col1" class="col_heading level0 col1" >webconversionrate</th>
#       <th id="T_43719_level0_col2" class="col_heading level0 col2" >dealpurchaseratio</th>
#       <th id="T_43719_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_43719_level0_col4" class="col_heading level0 col4" >income</th>
#       <th id="T_43719_level0_col5" class="col_heading level0 col5" >education</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
cluster_1_table = (
    pd.DataFrame([{
        "cluster": 1,
        "marital_status": df.loc[df["cluster"] == 1, "marital_status"].mean(),
        "costumertenuredays": df.loc[df["cluster"] == 1, "costumertenuredays"].mean(),
        "complain": df.loc[df["cluster"] == 1, "complain"].mean(),
        "campaignacceptancerate": df.loc[df["cluster"] == 1, "campaignacceptancerate"].mean(),
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_1_table
# Out:
# <style type="text/css">
# #T_be829 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_be829_row0_col0, #T_be829_row0_col1, #T_be829_row0_col2, #T_be829_row0_col3, #T_be829_row0_col4 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_be829">
#   <thead>
#     <tr>
#       <th id="T_be829_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_be829_level0_col1" class="col_heading level0 col1" >marital_status</th>
#       <th id="T_be829_level0_col2" class="col_heading level0 col2" >costumertenuredays</th>
#       <th id="T_be829_level0_col3" class="col_heading level0 col3" >complain</th>
#       <th id="T_be829_level0_col4" class="col_heading level0 col4" >campaignacceptancerate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_be829_row0_col0" class="data row0 col0" >1</td>
# ...

# %% [markdown]
# # 5. Cluster 2

# %%
cluster_2_table = (
    pd.DataFrame([{
        "cluster": 2,
        "numwebvisitsmonth": df.loc[df["cluster"] == 2, "numwebvisitsmonth"].mean(),
        "totalspending": df.loc[df["cluster"] == 2, "totalspending"].mean(),
        "totalpurchases": df.loc[df["cluster"] == 2, "totalpurchases"].mean(),
        "familysize": df.loc[df["cluster"] == 2, "familysize"].mean(),
        "spendingincomeratio": df.loc[df["cluster"] == 2, "spendingincomeratio"].mean(),
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_2_table
# Out:
# <style type="text/css">
# #T_77998 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_77998_row0_col0, #T_77998_row0_col1, #T_77998_row0_col2, #T_77998_row0_col3, #T_77998_row0_col4, #T_77998_row0_col5 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_77998">
#   <thead>
#     <tr>
#       <th id="T_77998_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_77998_level0_col1" class="col_heading level0 col1" >numwebvisitsmonth</th>
#       <th id="T_77998_level0_col2" class="col_heading level0 col2" >totalspending</th>
#       <th id="T_77998_level0_col3" class="col_heading level0 col3" >totalpurchases</th>
#       <th id="T_77998_level0_col4" class="col_heading level0 col4" >familysize</th>
#       <th id="T_77998_level0_col5" class="col_heading level0 col5" >spendingincomeratio</th>
#     </tr>
#   </thead>
# ...

# %%
cluster_2_table = (
    pd.DataFrame([{
        "cluster": 2,
        "webconversionrate": df.loc[df["cluster"] == 2, "webconversionrate"].mean(),
        "dealpurchaseratio": df.loc[df["cluster"] == 2, "dealpurchaseratio"].mean(),
        "age": df.loc[df["cluster"] == 2, "age"].mean(),
        "income": df.loc[df["cluster"] == 2, "income"].mean(),
        "education": df.loc[df["cluster"] == 2, "education"].mode().iloc[0],
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_2_table
# Out:
# <style type="text/css">
# #T_c8444 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_c8444_row0_col0, #T_c8444_row0_col1, #T_c8444_row0_col2, #T_c8444_row0_col3, #T_c8444_row0_col4, #T_c8444_row0_col5 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_c8444">
#   <thead>
#     <tr>
#       <th id="T_c8444_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_c8444_level0_col1" class="col_heading level0 col1" >webconversionrate</th>
#       <th id="T_c8444_level0_col2" class="col_heading level0 col2" >dealpurchaseratio</th>
#       <th id="T_c8444_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_c8444_level0_col4" class="col_heading level0 col4" >income</th>
#       <th id="T_c8444_level0_col5" class="col_heading level0 col5" >education</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
cluster_2_table = (
    pd.DataFrame([{
        "cluster": 2,
        "marital_status": df.loc[df["cluster"] == 2, "marital_status"].mean(),
        "costumertenuredays": df.loc[df["cluster"] == 2, "costumertenuredays"].mean(),
        "complain": df.loc[df["cluster"] == 2, "complain"].mean(),
        "campaignacceptancerate": df.loc[df["cluster"] == 2, "campaignacceptancerate"].mean(),
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_2_table
# Out:
# <style type="text/css">
# #T_b30f0 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_b30f0_row0_col0, #T_b30f0_row0_col1, #T_b30f0_row0_col2, #T_b30f0_row0_col3, #T_b30f0_row0_col4 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_b30f0">
#   <thead>
#     <tr>
#       <th id="T_b30f0_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_b30f0_level0_col1" class="col_heading level0 col1" >marital_status</th>
#       <th id="T_b30f0_level0_col2" class="col_heading level0 col2" >costumertenuredays</th>
#       <th id="T_b30f0_level0_col3" class="col_heading level0 col3" >complain</th>
#       <th id="T_b30f0_level0_col4" class="col_heading level0 col4" >campaignacceptancerate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b30f0_row0_col0" class="data row0 col0" >2</td>
# ...

# %% [markdown]
# # 6. Cluster 3

# %%
cluster_3_table = (
    pd.DataFrame([{
        "cluster": 3,
        "numwebvisitsmonth": df.loc[df["cluster"] == 3, "numwebvisitsmonth"].mean(),
        "totalspending": df.loc[df["cluster"] == 3, "totalspending"].mean(),
        "totalpurchases": df.loc[df["cluster"] == 3, "totalpurchases"].mean(),
        "familysize": df.loc[df["cluster"] == 3, "familysize"].mean(),
        "spendingincomeratio": df.loc[df["cluster"] == 3, "spendingincomeratio"].mean(),
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_3_table
# Out:
# <style type="text/css">
# #T_25e92 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_25e92_row0_col0, #T_25e92_row0_col1, #T_25e92_row0_col2, #T_25e92_row0_col3, #T_25e92_row0_col4, #T_25e92_row0_col5 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_25e92">
#   <thead>
#     <tr>
#       <th id="T_25e92_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_25e92_level0_col1" class="col_heading level0 col1" >numwebvisitsmonth</th>
#       <th id="T_25e92_level0_col2" class="col_heading level0 col2" >totalspending</th>
#       <th id="T_25e92_level0_col3" class="col_heading level0 col3" >totalpurchases</th>
#       <th id="T_25e92_level0_col4" class="col_heading level0 col4" >familysize</th>
#       <th id="T_25e92_level0_col5" class="col_heading level0 col5" >spendingincomeratio</th>
#     </tr>
#   </thead>
# ...

# %%
cluster_3_table = (
    pd.DataFrame([{
        "cluster": 3,
        "webconversionrate": df.loc[df["cluster"] == 3, "webconversionrate"].mean(),
        "dealpurchaseratio": df.loc[df["cluster"] == 3, "dealpurchaseratio"].mean(),
        "age": df.loc[df["cluster"] == 3, "age"].mean(),
        "income": df.loc[df["cluster"] == 3, "income"].mean(),
        "education": df.loc[df["cluster"] == 3, "education"].mode().iloc[0],
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_3_table
# Out:
# <style type="text/css">
# #T_11270 th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_11270_row0_col0, #T_11270_row0_col1, #T_11270_row0_col2, #T_11270_row0_col3, #T_11270_row0_col4, #T_11270_row0_col5 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_11270">
#   <thead>
#     <tr>
#       <th id="T_11270_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_11270_level0_col1" class="col_heading level0 col1" >webconversionrate</th>
#       <th id="T_11270_level0_col2" class="col_heading level0 col2" >dealpurchaseratio</th>
#       <th id="T_11270_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_11270_level0_col4" class="col_heading level0 col4" >income</th>
#       <th id="T_11270_level0_col5" class="col_heading level0 col5" >education</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
cluster_3_table = (
    pd.DataFrame([{
        "cluster": 3,
        "marital_status": df.loc[df["cluster"] == 3, "marital_status"].mean(),
        "costumertenuredays": df.loc[df["cluster"] == 3, "costumertenuredays"].mean(),
        "complain": df.loc[df["cluster"] == 3, "complain"].mean(),
        "campaignacceptancerate": df.loc[df["cluster"] == 3, "campaignacceptancerate"].mean(),
    }])
    .round(2)
    .style
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#111111",
        "color": "white",
        "border": "1px solid #333333",
        "text-align": "center",
    })
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111111"),
            ("color", "white"),
            ("border", "1px solid #333333"),
            ("text-align", "center"),
        ]}
    ])
)

cluster_3_table
# Out:
# <style type="text/css">
# #T_8bada th {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# #T_8bada_row0_col0, #T_8bada_row0_col1, #T_8bada_row0_col2, #T_8bada_row0_col3, #T_8bada_row0_col4 {
#   background-color: #111111;
#   color: white;
#   border: 1px solid #333333;
#   text-align: center;
# }
# </style>
# <table id="T_8bada">
#   <thead>
#     <tr>
#       <th id="T_8bada_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_8bada_level0_col1" class="col_heading level0 col1" >marital_status</th>
#       <th id="T_8bada_level0_col2" class="col_heading level0 col2" >costumertenuredays</th>
#       <th id="T_8bada_level0_col3" class="col_heading level0 col3" >complain</th>
#       <th id="T_8bada_level0_col4" class="col_heading level0 col4" >campaignacceptancerate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8bada_row0_col0" class="data row0 col0" >3</td>
# ...
